# %%
# !pip install ortools

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd "/content/gdrive/My Drive/python_projects/recover/GN2"
import os
input_file_path = os.path.join(".", "shakespeareMonkeys", "inputs")
input_files = [entry for entry in os.scandir(input_file_path) if entry.is_file()==True]
for i,j in enumerate(input_files):
  print("Use index {0} for file '{1}'".format(i,j))
# Out:
# /content/gdrive/My Drive/python_projects/recover/GN2
# Use index 0 for file '<DirEntry 'e_also_big.in'>'
# Use index 1 for file '<DirEntry 'b_small.in'>'
# Use index 2 for file '<DirEntry 'c_medium.in'>'
# Use index 3 for file '<DirEntry 'd_quite_big.in'>'
# Use index 4 for file '<DirEntry 'a_example.in'>'

# %%
from __future__ import print_function
from ortools.algorithms import pywrapknapsack_solver


def main(FILE_INDEX):
    # Create the solver.

    solver = pywrapknapsack_solver.KnapsackSolver(
        pywrapknapsack_solver.KnapsackSolver.
        KNAPSACK_MULTIDIMENSION_BRANCH_AND_BOUND_SOLVER, 'KnapsackExample')

    import os
    import numpy as np
    np.random.seed(101)
    input_file_path = os.path.join(".", "shakespeareMonkeys", "inputs")
    input_files = [entry for entry in os.scandir(input_file_path) if entry.is_file()==True]
    #for input_file in input_files:
    with open(input_files[FILE_INDEX].path) as f:
        print(f.name)
        file_contents = f.readlines()

    needed_amount_of_slices, number_of_types = np.array(file_contents[0][:-1].split(" ")).astype(np.int)
    slices_per_pizza_type = np.array(file_contents[1][:-1].split(" ")).astype(np.int)
    
    capacities = [needed_amount_of_slices]

    values = slices_per_pizza_type.tolist()
    weights = [slices_per_pizza_type.tolist()]

    solver.Init(values, weights, capacities)
    computed_value = solver.Solve()

    packed_items = []
    packed_weights = []
    total_weight = 0
    print('Total value =', computed_value)
    for i in range(len(values)):
        if solver.BestSolutionContains(i):
            packed_items.append(i)
            packed_weights.append(weights[0][i])
            total_weight += weights[0][i]
    print('Total weight:', total_weight)
    print('Packed items:', packed_items)
    print('Packed_weights:', packed_weights)

for i in range(0,5):
  # %time main(i)
# Out:
# ./shakespeareMonkeys/inputs/e_also_big.in
# Total value = 505000000
# Total weight: 505000000
# ...
